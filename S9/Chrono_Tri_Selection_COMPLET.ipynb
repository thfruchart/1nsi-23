# %% [markdown]
# ## 1. Tri par sélection
#
# **Compléter le code de la fonction suivante** pour qu'elle réalise le tri par sélection étudié en activité

# %%
def tri_par_selection(tab):
    for i in range ( len(tab)-1 ) :
        i_min = i 
        for j in range( i+1 , len(tab) ) : 
            if tab[j] < tab[i_min] : 
                i_min = j
        tab[i], tab[i_min] = tab[i_min], tab[i]
    return tab

# %%
# test 1
tri_par_selection([10,50,70,20,0,80,30])
# Out:
# [0, 10, 20, 30, 50, 70, 80]

# %%
# test 2
tri_par_selection([50,50,70,50,0,80,0])
# Out:
# [0, 0, 50, 50, 50, 70, 80]

# %% [markdown]
# ## 2. Tableau aléatoire de longueur n

# %% [markdown]
# On rappelle que la fonction `random`du module `random` renvoie un nombre aléatoire de type `float` compris entre 0 et 1.

# %%
from random import random

for _ in range(10):
    print( random() )
# Out:
# 0.6194544479837183
# 0.5214259084140639
# 0.39602792141612553
# 0.7458905013987366
# 0.9898959804054536
# 0.9738517060280143
# 0.8797610013312878
# 0.23296722263223946
# 0.176538709027955
# 0.3327090144370838

# %% [markdown]
# **Compléter le code de la fonction suivante** pour qu'elle renvoie un tableau de longueur n contenant des valeurs aléatoires de type `float`.

# %%
from random import random

def tableau_aleatoire(n):
    return [ random() for i in range(n) ]

# %%
# test 1 
tableau_aleatoire(5)
# Out:
# [0.36604139333926267, 0.38172910423309203, 0.3021698730802258, 0.4839213013211565, 0.7451366962111514]

# %%
# test 2
tableau_aleatoire(12)
# Out:
# [0.03968752039106871, 0.3237487592530155, 0.5797046379213715, 0.519053379534807, 0.7046495218267176, 0.40676334980560513, 0.3327424492293196, 0.3399012205049795, 0.9239875568494316, 0.735654656781858, 0.015419303969248843, 0.9936100460839574]

# %% [markdown]
# # 3. Mesurer le temps d'exécution

# %% [markdown]
# #### module `time`

# %% [markdown]
# Commencer par exécuter les trois cellules suivantes.
# Expliquer les résultats obtenus.

# %%
from time import time
t1 = time()
print(t1)
# Out:
# 1706791585.7580001

# %%
t2 = time()
print(t2)
# Out:
# 1706791586.573

# %%
delai = t2 - t1
print(delai)
# Out:
# 0.8149998188018799

# %%
help(time)
# Out:
# Help on built-in function time in module time:
#
# time(...)
#     time() -> floating point number
#
#     Return the current time in seconds since the Epoch.
#     Fractions of a second may be present if the system clock provides them.

# %% [markdown]
# #### chrono tri_par_selection
# utiliser les fonctions déjà programmées dans ce notebook pour compléter la fonction suivante, qui mesure le temps d'exécution du tri par sélection sur un tableau aléatoire de taille n.

# %%
def chrono_tri_sur_taille(n : int):
    ''' renvoie le temps (en milliseconde) d'exécution du tri par selection
    sur un tableau aléatoire de 'n' nombres flottants'''
    tab = tableau_aleatoire(n)
    start = time()
    tri_par_selection(tab)
    stop = time()
    delai = stop - start 
    return delai * 1000

# %%
chrono_tri_sur_taille(1000)
# Out:
# 51.000118255615234

# %%
chrono_tri_sur_taille(2000)
# Out:
# 216.00008010864258

# %%
chrono_tri_sur_taille(3000)
# Out:
# 429.0001392364502

# %%
chrono_tri_sur_taille(10000)
# Out:
# 9427.000045776367
