# %% [markdown]
# ## Mini-projet
#
# #### Conversion décimale => binaire pour les nombres flottants.
# En Python, il est facile de déterminer l'écriture binaire d'un nombre entier, avec la fonction `bin`.
# Tester les exemples ci-dessous :

# %%
bin(25)

# %%
bin(2**10)

# %%
bin(0.25)

# %% [markdown]
# => Problème : python ne gère pas la conversion binaire des nombres flottants

# %% [markdown]
# ### Objectif de ce mini projet :
# #### écrire un programme qui affiche à l'écran l'écriture binaire d'un nombre x saisi par l'utilisateur.

# %% [markdown]
# #### Remarques importantes
#
# * Puisque certains nombres flottants n'ont pas d'écriture binaire finie, il faudra limiter le nombre de chiffres affichés.
# * on pourra commencer par supposer que  `x` est compris entre 0 et 1.
# * on pourra ensuite améliorer la fonction en traitant les questions suivantes :
#   1. écrire une fonction `conversion_binaire(x:float)` qui **renvoye** l'écriture binaire au format `str` au lieu de l'afficher à l'écran.
#   2. laisser l'utilisateur choisir le nombre de chiffres après la virgule qu'il souhaite obtenir
#   3. traiter le cas où x est supérieur à 1

# %% [markdown]
# ## Organisation pratique

# %% [markdown]
# * Le travail s'effectue par binôme.
# * chaque binôme doit produire
#   * un **code** python par binôme (évalué sur 12 points)
#   * un **document** d'explication par élève (évalué sur 8 points), au format numérique (fichier texte, présentation...)

# %% [markdown]
# * le **code rendu** doit inclure des exemples (servant de démo).
# * le **document d'explication** doit présenter le code, en précisant notamment :
#   * la contribution de chaque élève au travail du groupe
#   * la spécification de chaque fonction :
#     * le rôle et le type des paramètres
#     * le rôle et le type de la valeur renvoyée
#     * le traitement réalisé par la fonction
#     * choix des structures d'exécution (boucle, conditionnelle, etc...)
#     * les tests réalisés pour cette fonction

# %% [markdown]
# ### AIDES
# Pour aider à la réalisation de ce mini-projet, on pourra utiliser les fonctions décrites dans les cellules suivantes :

# %% [markdown]
# #### aide 1 : Partie entière

# %%
# fonction floor 
from math import floor
print(floor(2.3))
print(floor(13.7))

# %% [markdown]
# #### aide 2 : Fonction `print`  [voir S0](https://github.com/thfruchart/1nsi/blob/main/S0/2ModeProgramme.ipynb)

# %%
# fonction print (rappel)
print('texte' , 2+2, end=' - - - ')
print('suite' , end=' +++ ')

# %% [markdown]
# #### aide 3 : opérations sur les chaînes de caractères (`str`)

# %%
txt = 'N'
print(txt)
txt = txt + 'S'
print(txt)
txt = txt + 'I'
print(txt)
