# %% [markdown]
# # Exercice 9 p.51

# %% [markdown]
# #### question 1
# Ecrire une instruction permettant de créer la liste `mois` des douze mois de l'année :
#
#     ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet',
#     'août', 'septembre', 'octobre', 'novembre', 'décembre']

# %%
mois = ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']

# %%
mois
# Out:
# ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']

# %% [markdown]
# #### question 2
# Avec la technique du *slicing* , écrire une instruction pour :

# %% [markdown]
# a) extraire de la liste `mois` uniquement les six premiers mois de l'année

# %%
mois[0:6]
# Out:
# ['janvier', 'février', 'mars', 'avril', 'mai', 'juin']

# %% [markdown]
# b) extraire les deux mois des grandes vacances !

# %%
mois[6:8]
# Out:
# ['juillet', 'août']

# %% [markdown]
# c) extraire la période de mars à octobre (inclus).

# %%
mois[2:10]
# Out:
# ['mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre']
