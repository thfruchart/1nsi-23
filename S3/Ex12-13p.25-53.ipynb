# %% [markdown]
# ## exercice 12  p. 52

# %% [markdown]
# 1. Compléter le code ci-dessous pour que la variable `panier` de type dictionnaire corresponde à l'image p.52

# %%
panier = { 'pomme'   : 2,
            'orange' : 2,
            'fraise' : 2,
             }

# %% [markdown]
# 2. Ecrire l'instruction python qui renvoie le nombre de kiwis

# %% [markdown]
# Ecrire l'instruction python qui renvoie le nombre de fraises

# %% [markdown]
# 3. Ecrire une instruction python permettant de vérifier le panier contient des oranges

# %% [markdown]
# Ecrire une instruction python permettant de vériifier que le panier ne contient PAS de mangues

# %% [markdown]
# 4. Que renvoie l'instruction `panier['mangues']` ?

# %% [markdown]
# ## exercice  13 p. 53

# %% [markdown]
# écrire une fonction `ajoute_fruit(panier, fruit, quantite)` qui ajoute le fruit dans le panier, avec la quantité indiquée.
#
# Tenir compte des deux cas :
# - fruit déjà présent dans le panier
# - nouveau fruit à ajouter
#
# La fonction renvoie le nouveau panier complété
