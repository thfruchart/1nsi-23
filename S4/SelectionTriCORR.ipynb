# %% [markdown]
# [ouvrir avec Basthon](https://notebook.basthon.fr/?from=https://raw.githubusercontent.com/thfruchart/1nsi/main/S4/Selection_Tri_Table.ipynb)

# %% [markdown]
# On a importé dans une variable `table` le contenu d'un fichier `sacs.csv` contenant la description d'une dizaine de sacs.
#
# L'objectif de ce notebook est de présenter deux opérations sur la table obtenue :
# * sélection
# * tri

# %%
table = [['id', 'nom', 'longueur', 'largeur', 'hauteur', 'couleur', 'poids', 'prix_HT', 'fabrique en France'], 
         ['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], 
         ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], 
         ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], 
         ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], 
         ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], 
         ['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non'], 
         ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], 
         ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], 
         ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non'], 
         ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui']]

# %% [markdown]
# ## Sélection

# %% [markdown]
# ### question 1
# En observant le code de la cellule suivante : que peut-on en déduire sur l'argument `critere` de la fonction `selectionner`?

# %%
def selectionner(table, critere):
    selection = []
    for i in range(1, len(table)):
        if critere(table[i]):
            selection.append(table[i])
    return selection

# %% [markdown]
# * critere(table[i]) est un **appel de fonction**  donc `critere` est une fonction.
# * `critere` doit renvoyer un booléen (à cause du `if`)
# * `critere` prend en paramètre une des lignes du tableau table

# %% [markdown]
# ### question 2
# Compléter le code de la fonction `madeinfrance` qui :
#
# *  prend un argument `sac`, de type `list`, décrivant un des sacs de la table,
# *  renvoie `True` si le sac est fabriqué en France, et `False` sinon.

# %%
def madeinfrance(sac):
    if sac[8] == 'oui'  : # ou sac[len(sac)-1]  ou sac[-1]
        return True
    else : 
        return False


# essai avec le premier sac:
print(madeinfrance(['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui']))
# essai avec le troisième sac : 
print(madeinfrance(['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non']))
# Out:
# True
# False

# %% [markdown]
# ### question 3
# Ecrire une instruction permettant d'obtenir la liste de tous les sacs de la table qui sont fabriqués en France.

# %%
selectionner(table, madeinfrance )
# Out:
# [['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui']]

# %% [markdown]
# ### question 4
# En vous inspirant des questions précédentes, écrire une fonction, et une instruction permettant d'obtenir la **liste des sacs bleus**.

# %%
def couleur_bleue(sac):
    if sac[5] == 'bleu'  :
        return True
    else : 
        return False

# %%
selectionner(table, couleur_bleue )
# Out:
# [['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non']]

# %%
[ sac for sac in table if sac[5] == 'bleu']
# Out:
# [['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non']]

# %% [markdown]
# ## Tri

# %% [markdown]
# On peut utiliser le tri par insertion ou le tri par sélection.
#
# On présente ici **l'usage basique** de la fonction `sorted` de Python : exécuter les cellules suivantes pour comprendre son fonctionnement.

# %%
sorted([10,50,30,40])
# Out:
# [10, 30, 40, 50]

# %%
sorted(['10','20','5','311'])
# Out:
# ['10', '20', '311', '5']

# %%
sorted(['ba','ca','e','dbb'])
# Out:
# ['ba', 'ca', 'dbb', 'e']

# %%
sorted([[10,20], [9,500], [11,0], [10,15]])
# Out:
# [[9, 500], [10, 15], [10, 20], [11, 0]]

# %%
t1 = [15,25,20,10,5]
t2 = sorted(t1)

print(t1)
print(t2)
# Out:
# [15, 25, 20, 10, 5]
# [5, 10, 15, 20, 25]

# %% [markdown]
# * La fonction `sorted` renvoie un tableau trié, sans modifier le tableau d'origine.
# * l'ordre de tri est l'ordre croissant : attention, l'ordre croissant sur les nombres n'est pas identique à l'ordre croissant sur les textes.
# * dans le cas d'une liste de listes, c'est le premier élément de chaque liste qui sert de critère de tri (puis le second... etc).

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
sorted([10,50,30,20,60], reverse = True )
# Out:
# [60, 50, 30, 20, 10]

# %% [markdown]
# Exemple de "custom key function"

# %%
def nom(sac):
    return sac[1]

# essai avec le premier sac:
print(nom(['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui']))
# essai avec le troisième sac : 
print(nom(['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non']))
# Out:
# trousse
# cabas

# %%
sorted(table, key=nom)
# Out:
# [['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui'], ['id', 'nom', 'longueur', 'largeur', 'hauteur', 'couleur', 'poids', 'prix_HT', 'fabrique en France'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non']]

# %%
sorted(table[1:], key=nom)
# Out:
# [['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non']]

# %% [markdown]
# ### question 5
# En vous inspirant de l'exemple ci-dessus, écrire une fonction et une instruction python permettant d'obtenir la liste des sacs triés par longueur croissante.

# %%
table[0]
# Out:
# ['id', 'nom', 'longueur', 'largeur', 'hauteur', 'couleur', 'poids', 'prix_HT', 'fabrique en France']

# %%
def longueur(sac):
    return float(sac[2])

def largeur(sac):
    return float(sac[3])

# %%
sorted(table[1:], key = longueur )
# Out:
# [['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non']]

# %%
sorted(table[1:], key = largeur )
# Out:
# [['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui'], ['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui']]

# %% [markdown]
# ### question 6
# Faire de même pour obtenir la liste des sacs, triés par **prix** décroissant.

# %%
def prix(sac) : 
    return float(sac[7])

# %%
sorted(table[1:], key = prix)
# Out:
# [['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non'], ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non']]

# %% [markdown]
# ### question 7
# Faire de même pour obtenir la liste des sacs, triés par **capacité** croissante.

# %%
def capacite(sac) : 
    return float(sac[2]) * float(sac[3]) * float(sac[4])

# %%
sorted(table[1:], key = capacite )
# Out:
# [['1', 'trousse', '20', '6', '7', 'bleu', '150', '18', 'oui'], ['10', 'minaudiere', '23', '5', '8', 'noir', '160', '35', 'oui'], ['9', 'wrist bag', '27', '16.5', '3.5', 'bleu', '125', '28', 'non'], ['5', 'banane', '23', '9', '13', 'noir', '260', '28', 'oui'], ['4', 'besace', '24', '21', '9', 'marron', '500', '84', 'oui'], ['8', 'seau', '24', '25', '13.5', 'noir', '430', '110', 'oui'], ['3', 'cabas', '35', '14', '30', 'bleu', '330', '95', 'non'], ['7', 'sac à dos', '30', '40', '18', 'gris', '375', '50', 'oui'], ['2', 'polochon', '50', '25', '25', 'rouge', '450', '79', 'oui'], ['6', 'baluchon', '61', '38', '22', 'beige', '900', '145', 'non']]
